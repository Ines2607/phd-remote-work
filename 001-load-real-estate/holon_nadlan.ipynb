# 19  10.05.2024  2024-05-10T00:00:00          חנקין 117, חולון
# 0   30.05.2024  2024-05-30T00:00:00        נעמי שמר 12, חולון
# 1   30.05.2024  2024-05-30T00:00:00  רבינוביץ יהושע 83, חולון
# 2   27.05.2024  2024-05-27T00:00:00             הדר 26, חולון
# 3   26.05.2024  2024-05-26T00:00:00       רמת הגולן 33, חולון
# 4   23.05.2024  2024-05-23T00:00:00      יהודה הלוי 13, חולון
# 5   23.05.2024  2024-05-23T00:00:00        סוקולוב 116, חולון
# 6   21.05.2024  2024-05-21T00:00:00        אחד במאי 50, חולון
# 7   20.05.2024  2024-05-20T00:00:00             הדס 20, חולון
# 8   20.05.2024  2024-05-20T00:00:00       אמיר דרורי 2, חולון
# 9   20.05.2024  2024-05-20T00:00:00           חנקין 36, חולון
# 10  19.05.2024  2024-05-19T00:00:00          התחייה 22, חולון
# 11  19.05.2024  2024-05-19T00:00:00          הצנחנים 3, חולון
# 12  19.05.2024  2024-05-19T00:00:00         עמק דותן 1, חולון
# 13  16.05.2024  2024-05-16T00:00:00       ארלוזורוב 17, חולון
# 14  15.05.2024  2024-05-15T00:00:00       פרופ' שור 45, חולון
# 15  15.05.2024  2024-05-15T00:00:00          דב הוז 67, חולון
# 16  15.05.2024  2024-05-15T00:00:00       ארלוזורוב 17, חולון
# 17  13.05.2024  2024-05-13T00:00:00           הגר"א 26, חולון
# 18  12.05.2024  2024-05-12T00:00:00        דוד אלעזר 7, חולון
# 19  10.05.2024  2024-05-10T00:00:00          חנקין 117, חולון
#
#         DISPLAYADRESS         GUSH DEALNATUREDESCRIPTION ASSETROOMNUM  \
# 0         נעמי שמר 12   6872-17-30       דירה בבית קומות            5
# 1   רבינוביץ יהושע 83    7183-25-7       דירה בבית קומות            4
# 2              הדר 26  6996-127-12       דירה בבית קומות            4
# 3        רמת הגולן 33   7342-46-31       דירה בבית קומות            3
# 4       יהודה הלוי 13   7171-84-10       דירה בבית קומות            3
# 5         סוקולוב 116   7169-128-7       דירה בבית קומות            2
# 6         אחד במאי 50   7176-107-3                  None            2
# 7              הדס 20   6870-81-28       דירה בבית קומות            4
# 8        אמיר דרורי 2   6870-84-42       דירה בבית קומות            4
# 9            חנקין 36  7168-166-12       דירה בבית קומות          3.5
# 10          התחייה 22  6021-949-22       דירה בבית קומות            4
# 11          הצנחנים 3    7167-74-5       דירה בבית קומות            5
# 12         עמק דותן 1   7341-32-13       דירה בבית קומות            3
# 13       ארלוזורוב 17   7170-44-19       דירה בבית קומות            3
# 14       פרופ' שור 45   6779-55-21       דירה בבית קומות            5
# 15          דב הוז 67   7162-202-8       דירה בבית קומות            3
# 16       ארלוזורוב 17   7170-44-18                  None            5
# 17           הגר"א 26  7162-229-10       דירה בבית קומות            4
# 18        דוד אלעזר 7   6020-318-3       דירה בבית קומות            3
# 19          חנקין 117  6021-522-24       דירה בבית קומות            2
# 0         נעמי שמר 12   6872-17-30       דירה בבית קומות            5
# 1   רבינוביץ יהושע 83    7183-25-7       דירה בבית קומות            4
# 2              הדר 26  6996-127-12       דירה בבית קומות            4
# 3        רמת הגולן 33   7342-46-31       דירה בבית קומות            3
# 4       יהודה הלוי 13   7171-84-10       דירה בבית קומות            3
# 5         סוקולוב 116   7169-128-7       דירה בבית קומות            2
# 6         אחד במאי 50   7176-107-3                  None            2
# 7              הדס 20   6870-81-28       דירה בבית קומות            4
# 8        אמיר דרורי 2   6870-84-42       דירה בבית קומות            4
# 9            חנקין 36  7168-166-12       דירה בבית קומות          3.5
# 10          התחייה 22  6021-949-22       דירה בבית קומות            4
# 11          הצנחנים 3    7167-74-5       דירה בבית קומות            5
# 12         עמק דותן 1   7341-32-13       דירה בבית קומות            3
# 13       ארלוזורוב 17   7170-44-19       דירה בבית קומות            3
# 14       פרופ' שור 45   6779-55-21       דירה בבית קומות            5
# 15          דב הוז 67   7162-202-8       דירה בבית קומות            3
# 16       ארלוזורוב 17   7170-44-18                  None            5
# 17           הגר"א 26  7162-229-10       דירה בבית קומות            4
# 18        דוד אלעזר 7   6020-318-3       דירה בבית קומות            3
# 19          חנקין 117  6021-522-24       דירה בבית קומות            2
# 0         נעמי שמר 12   6872-17-30       דירה בבית קומות            5
# 1   רבינוביץ יהושע 83    7183-25-7       דירה בבית קומות            4
# 2              הדר 26  6996-127-12       דירה בבית קומות            4
# 3        רמת הגולן 33   7342-46-31       דירה בבית קומות            3
# 4       יהודה הלוי 13   7171-84-10       דירה בבית קומות            3
# 5         סוקולוב 116   7169-128-7       דירה בבית קומות            2
# 6         אחד במאי 50   7176-107-3                  None            2
# 7              הדס 20   6870-81-28       דירה בבית קומות            4
# 8        אמיר דרורי 2   6870-84-42       דירה בבית קומות            4
# 9            חנקין 36  7168-166-12       דירה בבית קומות          3.5
# 10          התחייה 22  6021-949-22       דירה בבית קומות            4
# 11          הצנחנים 3    7167-74-5       דירה בבית קומות            5
# 12         עמק דותן 1   7341-32-13       דירה בבית קומות            3
# 13       ארלוזורוב 17   7170-44-19       דירה בבית קומות            3
# 14       פרופ' שור 45   6779-55-21       דירה בבית קומות            5
# 15          דב הוז 67   7162-202-8       דירה בבית קומות            3
# 16       ארלוזורוב 17   7170-44-18                  None            5
# 17           הגר"א 26  7162-229-10       דירה בבית קומות            4
# 18        דוד אלעזר 7   6020-318-3       דירה בבית קומות            3
# 19          חנקין 117  6021-522-24       דירה בבית קומות            2
#
#       FLOORNO DEALNATURE DEALAMOUNT NEWPROJECTTEXT PROJECTNAME BUILDINGYEAR  \
# 0      שביעית     120.88  3,170,000                       None         2009
# 1      שלישית         99  2,250,000                       None         1995
# 2       שישית      74.36  2,270,000                       None         1997
# 3      רביעית         61  1,800,000                       None         1970
# 4      רביעית      57.73  1,650,000                       None         1970
# 5      ראשונה      61.14  1,740,000                       None         1960
# 6      ראשונה         38  2,120,000                       None         1960
# 7      שביעית     124.15  3,100,000                       None         2008
# 8   קומה ‎11‏     108.75  2,800,000                       None         2005
# 9      רביעית         58  2,000,000                       None         1950
# 10      שישית      97.22  2,450,000                       None         1970
# 11     חמישית        173  3,930,000                       None         1951
# 12     רביעית         73  1,700,000                       None         1970
# 13       שניה         78  2,455,000                       None         1930
# 14      שישית         98  1,175,000                       None         1989
# 15       שניה      67.59  1,720,000                       None         1970
# 16     רביעית        130  3,570,000              1        None         1930
# 17     שלישית      72.84  1,790,000                       None         1995
# 18     ראשונה         67  2,075,000                       None         2025
# 19     ראשונה      36.60  1,740,000                       None         1960
# 0      שביעית     120.88  3,170,000                       None         2009
# 1      שלישית         99  2,250,000                       None         1995
# 2       שישית      74.36  2,270,000                       None         1997
# 3      רביעית         61  1,800,000                       None         1970
# 4      רביעית      57.73  1,650,000                       None         1970
# 17                        4   3600426734     1   7162-229              False
# 18                        1   3600652557     1   6020-318              False
# 19                        2   3600477426     1   6021-522              False
# 0                        11   3600917414     1    6872-17              False
# 1                        10   3600921967     1    7183-25              False
# 2                         6   3600831284     1   6996-127              False
# 3                         4   3600812405     1    7342-46              False
# 4                         4   3600803995     1    7171-84              False
# 5                         2   3600811187     1   7169-128              False
# 6                         3   3600692519     1   7176-107              False
# 7                        13   3600842768     1    6870-81              False
# 8                        15   3600807852     1    6870-84              False
# 9                         3   3600618308     1   7168-166              False
# 10                        9   3600561120     1   6021-949              False
# 11      2026              1   3600581275     1    7167-74              False
# 12                        7   3600542763     1    7341-32              False
# 13      2026              6   3600733931     1    7170-44              False
# 14                        9   3600488910     1    6779-55              False
# 15                        3   3600519998     1   7162-202              False
# 16                        6  11171539210     1    7170-44              False
# 17                        4   3600426734     1   7162-229              False
# 18                        1   3600652557     1   6020-318              False
# 19                        2   3600477426     1   6021-522              False
#
#         TREND_FORMAT
# 0    70% ב 12.9 שנים
# 1   207% ב 19.4 שנים
# 2   145% ב 16.2 שנים
# 3
# 4     15% ב 2.3 שנים
# 5     45% ב 4.6 שנים
# 6
# 7
# 8    75% ב 14.5 שנים
# 9
# 10
# 11
# 12
# 13
# 14  135% ב 15.5 שנים
# 15
# 16
# 17    28% ב 7.5 שנים
# 18
# 19      16% ב 1 שנים
# 0    70% ב 12.9 שנים
# 1   207% ב 19.4 שנים
# 2   145% ב 16.2 שנים
# 3
# 4     15% ב 2.3 שנים
# 5     45% ב 4.6 שנים
# 6
# 7
# 8    75% ב 14.5 שנים
# 9
# 10
# 11
# 12
# 13
# 14  135% ב 15.5 שנים
# 15
# 16
# 17    28% ב 7.5 שנים
# 18
# 19      16% ב 1 שנים
# 0    70% ב 12.9 שנים
# 1   207% ב 19.4 שנים
# 2   145% ב 16.2 שנים
# 3
# 4     15% ב 2.3 שנים
# 5     45% ב 4.6 שנים
# 6
# 7
# 8    75% ב 14.5 שנים
# 9
# 10
# 11
# 12
# 13
# 14  135% ב 15.5 שנים
# 15
# 16
# 17    28% ב 7.5 שנים
# 18
# 19      16% ב 1 שנים

# %%
df_full=pd.DataFrame()
for start_n in np.arange(1,2001,200):
    
    for pagenum in tqdm(range(start_n,start_n+200)):
        data = {"MoreAssestsType":0,"FillterRoomNum":0,"GridDisplayType":0,
            "ResultLable":city_name,
            "ResultType":1,
            "ObjectID":objid,"ObjectIDType":"text","ObjectKey":"UNIQ_ID",
            "DescLayerID":"SETL_MID_POINT","Alert":None,
            "X":X,
            "Y":Y,
            "Gush":"","Parcel":"","showLotParcel":True,
            "showLotAddress":True,"OriginalSearchString":city_name,"MutipuleResults":False,
            "ResultsOptions":None,
            "CurrentLavel":2,
            "Navs":[{"text":None,"url":None,"order":1}],
            "QueryMapParams":{"QueryToRun":None,"QueryObjectID":objid,"QueryObjectType":"number",
                              "QueryObjectKey":"SETL_CODE","QueryDescLayerID":"KSHTANN_SETL_AREA","SpacialWhereClause":None},
            "isHistorical":True,
            "PageNo":pagenum,
            "OrderByFilled":"DEALDATETIME","OrderByDescending":True,"Distance":0}
        result = requests.post(url, json=data).json()
        list_res.append(result)
    
    for r in list_res:
        df= pd.DataFrame(r["AllResults"])
        df_full = pd.concat([df,df_full])
    df_full.to_csv(f"holon_nadlan_pages{start_n}_{start_n+200}.csv")
# Out:
# 100%|█████████████████████████████████████████| 200/200 [25:17<00:00,  7.59s/it]
# 100%|█████████████████████████████████████████| 200/200 [25:43<00:00,  7.72s/it]
# 100%|█████████████████████████████████████████| 200/200 [25:48<00:00,  7.74s/it]
# 100%|█████████████████████████████████████████| 200/200 [28:57<00:00,  8.69s/it]
# 100%|█████████████████████████████████████████| 200/200 [25:05<00:00,  7.53s/it]
#   4%|█▋                                         | 8/200 [01:01<24:01,  7.51s/it]

# %%
o

# %%
start_n=801

data = pd.read_csv(f"holon_nadlan_pages{start_n}_{start_n+200}.csv")

data = data.drop_duplicates()

# df_full=pd.DataFrame()

data
# Out:
#        Unnamed: 0    DEALDATE         DEALDATETIME             FULLADRESS  \
# 0               0  15.11.2013  2013-11-15T00:00:00        נורדאו 7, חולון
# 1               1  15.11.2013  2013-11-15T00:00:00    יוסף הנשיא 3, חולון
# 2               2  14.11.2013  2013-11-14T00:00:00       התחייה 19, חולון
# 3               3  14.11.2013  2013-11-14T00:00:00  יצחק וולקני 13, חולון
# 4               4  14.11.2013  2013-11-14T00:00:00                    NaN
# ...           ...         ...                  ...                    ...
# 19995          15  15.05.2024  2024-05-15T00:00:00       דב הוז 67, חולון
# 19996          16  15.05.2024  2024-05-15T00:00:00    ארלוזורוב 17, חולון
# 19997          17  13.05.2024  2024-05-13T00:00:00        הגר"א 26, חולון
# 19998          18  12.05.2024  2024-05-12T00:00:00     דוד אלעזר 7, חולון
# 19999          19  10.05.2024  2024-05-10T00:00:00       חנקין 117, חולון
#
#         DISPLAYADRESS         GUSH DEALNATUREDESCRIPTION  ASSETROOMNUM  \
# 0            נורדאו 7   7167-118-3       דירה בבית קומות           4.0
# 1        יוסף הנשיא 3   7171-117-6       דירה בבית קומות           3.0
# 2           התחייה 19  6021-940-45       דירה בבית קומות           2.5
# 3      יצחק וולקני 13  6049-269-12       דירה בבית קומות           3.0
# 4                 NaN   6869-11-27       דירה בבית קומות           4.0
# ...               ...          ...                   ...           ...
# 19995       דב הוז 67   7162-202-8       דירה בבית קומות           3.0
# 19996    ארלוזורוב 17   7170-44-18                   NaN           5.0
# 19997        הגר"א 26  7162-229-10       דירה בבית קומות           4.0
# 19998     דוד אלעזר 7   6020-318-3       דירה בבית קומות           3.0
# 19999       חנקין 117  6021-522-24       דירה בבית קומות           2.0
#
#         FLOORNO  DEALNATURE  ... NEWPROJECTTEXT  PROJECTNAME BUILDINGYEAR  \
# 0          שניה       63.20  ...            NaN          NaN       1960.0
# 1          שניה       65.08  ...            NaN          NaN       2004.0
# 2        רביעית       42.40  ...            NaN          NaN       1960.0
# 3        שלישית       57.23  ...            NaN          NaN       1970.0
# 4      קומה ‎7‏      113.15  ...            NaN          NaN          NaN
# ...         ...         ...  ...            ...          ...          ...
# 19995      שניה       67.59  ...            NaN          NaN       1970.0
# 19996    רביעית      130.00  ...            1.0          NaN       1930.0
# 19997    שלישית       72.84  ...            NaN          NaN       1995.0
# 19998    ראשונה       67.00  ...            NaN          NaN       2025.0
# 19999    ראשונה       36.60  ...            NaN          NaN       1960.0
#
#        YEARBUILT  BUILDINGFLOORS     KEYVALUE  TYPE  POLYGON_ID  \
# 0            NaN             3.0   3286494049     1    7167-118
# 1            NaN             4.0   3286496920     1    7171-117
# 2            NaN             4.0   3287017789     1    6021-940
# 3            NaN             3.0   3286500777     1    6049-269
# 4            NaN             NaN   3286692177     2     6869-11
# ...          ...             ...          ...   ...         ...
# 19995        NaN             3.0   3600519998     1    7162-202
# 19996        NaN             6.0  11171539210     1     7170-44
# 19997        NaN             4.0   3600426734     1    7162-229
# 19998        NaN             1.0   3600652557     1    6020-318
# 19999        NaN             2.0   3600477426     1    6021-522
#
#       TREND_IS_NEGATIVE    TREND_FORMAT
# 0                 False             NaN
# 1                 False  86% ב 9.5 שנים
# 2                 False    97% ב 6 שנים
# 3                 False  84% ב 7.3 שנים
# 4                 False             NaN
# ...                 ...             ...
# 19995             False             NaN
# 19996             False             NaN
# 19997             False  28% ב 7.5 שנים
# 19998             False             NaN
# 19999             False    16% ב 1 שנים
#
# [20000 rows x 21 columns]
